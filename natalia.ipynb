# %%
pip install lxml Pyarrow requests pandas
# Out:
# Requirement already satisfied: lxml in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (5.2.1)
# Requirement already satisfied: Pyarrow in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (15.0.2)
# Requirement already satisfied: requests in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (2.31.0)
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.16.6 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from Pyarrow) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\natal\desktop\natalia\test\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 330.3 kB/s eta 0:00:35
#    ---------------------------------------- 0.0/11.5 MB 330.3 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/11.5 MB 655.4 kB/s eta 0:00:18
#     --------------------------------------- 0.2/11.5 MB 958.1 kB/s eta 0:00:12
#     --------------------------------------- 0.3/11.5 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/11.5 MB 1.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.5 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.5 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.7/11.5 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.5 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.5 MB 2.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.2/11.5 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.4/11.5 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.4/11.5 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/11.5 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.5 MB 2.3 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.5 MB 2.4 MB/s eta 0:00:05
#    ------- -------------------------------- 2.0/11.5 MB 2.5 MB/s eta 0:00:04
#    ------- -------------------------------- 2.2/11.5 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.5 MB 2.7 MB/s eta 0:00:04
#    -------- ------------------------------- 2.5/11.5 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.7/11.5 MB 2.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.5 MB 2.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/11.5 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.3/11.5 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.5/11.5 MB 3.0 MB/s eta 0:00:03
#    ------------ --------------------------- 3.6/11.5 MB 3.0 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.5 MB 3.0 MB/s eta 0:00:03
#    -------------- ------------------------- 4.1/11.5 MB 3.0 MB/s eta 0:00:03
#    --------------- ------------------------ 4.3/11.5 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 2.9 MB/s eta 0:00:03
#    --------------- ------------------------ 4.6/11.5 MB 3.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.8/11.5 MB 3.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.8/11.5 MB 3.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.9/11.5 MB 2.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 2.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.1/11.5 MB 2.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.1/11.5 MB 2.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.1/11.5 MB 2.9 MB/s eta 0:00:03
#    ------------------ --------------------- 5.3/11.5 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.5 MB 2.8 MB/s eta 0:00:03
#    ------------------- -------------------- 5.7/11.5 MB 2.8 MB/s eta 0:00:03
#    -------------------- ------------------- 5.9/11.5 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.1/11.5 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.5 MB 2.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.5/11.5 MB 2.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.5 MB 3.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.5 MB 3.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.7/11.5 MB 2.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.0/11.5 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.2/11.5 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.2/11.5 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.5 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 7.4/11.5 MB 2.8 MB/s eta 0:00:02
#    -------------------------- ------------- 7.5/11.5 MB 2.8 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.5 MB 2.8 MB/s eta 0:00:02
#    --------------------------- ------------ 7.8/11.5 MB 2.8 MB/s eta 0:00:02
#    --------------------------- ------------ 8.0/11.5 MB 2.8 MB/s eta 0:00:02
#    --------------------------- ------------ 8.0/11.5 MB 2.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.5 MB 2.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.5 MB 2.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.5/11.5 MB 2.8 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.8/11.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.8/11.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.5 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 2.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.3/11.5 MB 2.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.5 MB 2.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.8/11.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.5 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.5 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 2.9 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests 
from datetime import datetime
from io import StringIO

# %%
# Parameters for URL

report_type = 'HistoricalPoolPriceReportServlet' # Type of report
start_date = '02282020' # Start date for the data range of the report: February 28, 2020
end_date = '02282021' # End date for the data range of the report: February 28, 2021
content_type = 'html' # Type of content expected from the AESO server

# Date range check "Manually"

start_date_datatime = datetime.strptime(start_date, '%m%d%Y')
end_date_datatime = datetime.strptime(end_date, '%m%d%Y')
time_delta = end_date_datatime - start_date_datatime
time_delta

# Date range check "Conditional statement"

if time_delta.days <= 366:
    print("The selected data range is within the acceptable limit of 366 days.")
elif time_delta.days >= 366:
    print("Please select a new data range as this report is available for a maximum of 366 days of data.")
    import sys
    sys.exit(1)

# URL for web scrape
url = 'http://ets.aeso.ca/ets_web/ip/Market/Reports/{}?beginDate={}&endDate={}&contentType={}'.format(report_type, start_date, end_date, content_type)
print(url)

''' The placeholders {} in the URL string will be replaced with the values of report_type, 
start_date, end_date, and content_type
'''

# Get HTML content using the requests library
source = requests.get(url).text  # The .text attribute extracts the HTML content as plain text

# Wrap HTML content in StringIO object
html_buffer = StringIO(source)

# Parse the HTML content (stored in source) into a list of DataFrames 
df_list = pd.read_html(html_buffer)  # pd.read_html() searches for table elements and creates a df for each of them
print('number of tables =',  len(df_list)) 

# Create a DataFrame containing the data stored on table #2 (Index = 1) in the HTML
df = df_list[1]

# Display the DataFrame
df
# Out:
# The selected data range is within the acceptable limit of 366 days.
# http://ets.aeso.ca/ets_web/ip/Market/Reports/HistoricalPoolPriceReportServlet?beginDate=02282020&endDate=02282021&contentType=html
# number of tables = 2
#           Date (HE)  Price ($)  30Ravg ($)  AIL Demand (MW)
# 0     02/28/2020 01      29.31       36.10           9358.0
# 1     02/28/2020 02      29.89       36.10           9228.0
# 2     02/28/2020 03      29.94       36.09           9161.0
# 3     02/28/2020 04      29.88       36.08           9140.0
# 4     02/28/2020 05      29.84       36.08           9186.0
# ...             ...        ...         ...              ...
# 8779  02/27/2021 20      42.21      149.96          10729.0
# 8780  02/27/2021 21      26.74      149.92          10680.0
# 8781  02/27/2021 22      27.18      149.89          10567.0
# 8782  02/27/2021 23      35.90      149.88          10359.0
# 8783  02/27/2021 24      38.78      149.87          10108.0
#
# [8784 rows x 4 columns]
